# %%
import pandas as pd

# %%
df = pd.read_csv("/content/covid_toy - covid_toy.csv")

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
# Descreate(Categorical)--> we cannot divided further. ex. result(pass\fail), marital status, number of employees
# Continuous(numerical)--> we can divided further. ex. distance(km), birth

# %%
# if data is descreate --> most frequent
# if data is continuous --> mean

# %%
df['fever'] = df['fever'].fillna(df['fever'].mean())

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
df['gender']=df['gender'].map({'Female':0, 'Male':1})

# %%
df['cough']=df['cough'].map({'Mild':0, 'Strong':1})

# %%
df['city']=df['city'].map({'Kolkata':0, 'Bangalore':1, 'Delhi':2, 'Mumbai':3})

# %%
df['has_covid']=df['has_covid'].map({'No':0, 'Yes':1})

# %%
df.sample(5)
# Out:
#     age  gender  fever  cough  city  has_covid
# 57   49       0   99.0      1     1          0
# 84   69       0   98.0      1     3          0
# 66   51       1  104.0      0     0          0
# 37   55       1  100.0      0     0          0
# 87   47       1  101.0      1     1          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    int64
#  2   fever      100 non-null    float64
#  3   cough      100 non-null    int64
#  4   city       100 non-null    int64
#  5   has_covid  100 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 4.8 KB

# %%
df.describe() ## statically view of data
# Out:
#               age      gender       fever       cough        city  has_covid
# count  100.000000  100.000000  100.000000  100.000000  100.000000     100.00
# mean    44.220000    0.410000  100.844444    0.380000    1.220000       0.45
# std     24.878931    0.494311    1.948380    0.487832    1.069126       0.50
# min      5.000000    0.000000   98.000000    0.000000    0.000000       0.00
# 25%     20.000000    0.000000   99.000000    0.000000    0.000000       0.00
# 50%     45.000000    0.000000  100.922222    0.000000    1.000000       0.00
# 75%     66.500000    1.000000  102.000000    1.000000    2.000000       1.00
# max     84.000000    1.000000  104.000000    1.000000    3.000000       1.00

# %%
df_new = pd.read_csv("/content/covid_toy - covid_toy.csv")

# %%
df_new = df_new.dropna()

# %%
df_new.describe()
# Out:
#              age       fever
# count  90.000000   90.000000
# mean   43.044444  100.844444
# std    24.651235    2.054926
# min     5.000000   98.000000
# 25%    19.250000   99.000000
# 50%    45.000000  101.000000
# 75%    65.000000  102.750000
# max    83.000000  104.000000

# %%
df.head()
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     0          0
# 1   27       1  100.0      0     2          1
# 2   42       1  101.0      0     2          0
# 3   31       0   98.0      0     0          0
# 4   65       0  101.0      0     3          0

# %%
## centroid ---> mean, meadian, mode

# %%
df['fever'] = df['fever'].astype(int) #change the type of the data

# %%
a = df[['gender','fever']][3:7]=50
# Out:
# /tmp/ipython-input-3155208441.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a = df[['gender','fever']][3:7]=50

# %%
df['fever'][2]=500
# Out:
# /tmp/ipython-input-2610728801.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['fever'][2]=500

# %%
df.head()
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1    103      0     0          0
# 1   27       1    100      0     2          1
# 2   42       1    500      0     2          0
# 3   31       0     98      0     0          0
# 4   65       0    101      0     3          0

# %%
df = df.rename(columns = {'fever':'updated_fever'})

# %%
df.head()
# Out:
#    age  gender  updated_fever  cough  city  has_covid
# 0   60       1            103      0     0          0
# 1   27       1            100      0     2          1
# 2   42       1            500      0     2          0
# 3   31       0             98      0     0          0
# 4   65       0            101      0     3          0

# %%
# EDA ==> Exploratory Data Analysis

# %%
# Parts of EDA

# %%
# 1.Universal Analysis --> Analysis on a single independent column
# 2.Bivariate Analysis --> Analysis on two independent column
# 3.Multivariate Analysis --> Analysis on more than two independent column

# %%
import pandas as pd
import numpy as np

# %%
! pip install matplotlib
! pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/titanic - titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# if we want to see actual values then we use value_count()

df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
# Categorical data
sns.countplot( x=df['Survived'])  # x --> x is axis
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# Bar chart
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
#Pie chart
df['Survived'].value_counts().plot(kind = 'pie', autopct = '%2f')
# Out:
# <Axes: ylabel='count'>

# %%
# Nu
# if we have numerical data then we use Histogram
# because it finds the distribution

# %%
plt.hist(x=df['Age'])
plt.show()
